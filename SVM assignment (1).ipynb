# %%
import joblib
import pandas as pd
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
import warnings
import pandas as pd
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=DeprecationWarning)
tr_features = pd.read_csv("heart.csv")
tr_labels = pd.read_csv("heart.csv", header=None)

# %%
import pandas as pd
Heart=pd.read_csv("heart.csv")
print(Heart.shape)
print(Heart.describe())
print(Heart.head())
# Out:
# (303, 14)
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
def print_results(results):
    print('BEST PARAMS: {}\n'.format(results.best_params_))

    means = results.cv_results_['mean_test_score']
    stds = results.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, results.cv_results_['params']):
        print('{} (+/-{}) for {}'.format(round(mean, 3), round(std * 2, 3), params))

# %%
tr_features = pd.read_csv("heart.csv")
X = tr_features.iloc[:, :-1]
y = tr_features["target"]
svc = SVC()
parameters = {
  'kernel': ['linear', 'rbf'],
  'C': [0.1, 1, 10]
}

# %%
cv = GridSearchCV(svc, parameters, cv=5)
cv.fit(X, y)
print(cv.best_params_)
print(cv.cv_results_)
# Out:
# {'C': 1, 'kernel': 'linear'}
# {'mean_fit_time': array([0.05450764, 0.00658264, 0.53715653, 0.00641952, 4.0897912 ,
#        0.00601325]), 'std_fit_time': array([1.93143237e-02, 9.62972028e-04, 2.89044504e-01, 5.02018105e-04,
#        1.01581040e+00, 2.07764719e-04]), 'mean_score_time': array([0.0037312 , 0.00379386, 0.00305452, 0.00351725, 0.00395365,
#        0.0034318 ]), 'std_score_time': array([1.68862163e-03, 8.81495848e-04, 7.58263444e-05, 2.27322262e-04,
#        1.58699799e-03, 1.47102138e-04]), 'param_C': masked_array(data=[0.1, 0.1, 1, 1, 10, 10],
#              mask=[False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_kernel': masked_array(data=['linear', 'rbf', 'linear', 'rbf', 'linear', 'rbf'],
#              mask=[False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'C': 0.1, 'kernel': 'linear'}, {'C': 0.1, 'kernel': 'rbf'}, {'C': 1, 'kernel': 'linear'}, {'C': 1, 'kernel': 'rbf'}, {'C': 10, 'kernel': 'linear'}, {'C': 10, 'kernel': 'rbf'}], 'split0_test_score': array([0.81967213, 0.54098361, 0.81967213, 0.60655738, 0.7704918 ,
#        0.67213115]), 'split1_test_score': array([0.8852459 , 0.54098361, 0.8852459 , 0.60655738, 0.91803279,
#        0.68852459]), 'split2_test_score': array([0.83606557, 0.54098361, 0.80327869, 0.73770492, 0.7704918 ,
#        0.70491803]), 'split3_test_score': array([0.81666667, 0.55      , 0.86666667, 0.68333333, 0.86666667,
#        0.73333333]), 'split4_test_score': array([0.73333333, 0.55      , 0.76666667, 0.58333333, 0.76666667,
#        0.7       ]), 'mean_test_score': array([0.81819672, 0.54459016, 0.82830601, 0.64349727, 0.81846995,
#        0.69978142]), 'std_test_score': array([0.04903305, 0.00441711, 0.04292787, 0.05798414, 0.06248691,
#        0.02021592]), 'rank_test_score': array([3, 6, 1, 5, 2, 4], dtype=int32)}

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cv.best_estimator_
print_results(cv)
# Out:
# BEST PARAMS: {'C': 1, 'kernel': 'linear'}
#
# 0.818 (+/-0.098) for {'C': 0.1, 'kernel': 'linear'}
# 0.545 (+/-0.009) for {'C': 0.1, 'kernel': 'rbf'}
# 0.828 (+/-0.086) for {'C': 1, 'kernel': 'linear'}
# 0.643 (+/-0.116) for {'C': 1, 'kernel': 'rbf'}
# 0.818 (+/-0.125) for {'C': 10, 'kernel': 'linear'}
# 0.7 (+/-0.04) for {'C': 10, 'kernel': 'rbf'}
